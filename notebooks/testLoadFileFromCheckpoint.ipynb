# %%
import os
from config import CHECKPOINT_PATH
from pathlib import Path

from helper import getRootPath

# %% [markdown]
# ### Trial

# %%
targetPath = os.path.join(CHECKPOINT_PATH, "testLoad.txt")
print(targetPath)
# Out:
# .\checkpoint\testLoad.txt

# %%
ROOT_DIR = Path.cwd()
print(ROOT_DIR)
# Out:
# d:\python\llm-scratch\notebooks

# %%
currentPath = str(ROOT_DIR)

# %%
projectPath = currentPath.find("llm-scratch")

# %%
currentPath[0: projectPath + len("llm-scratch")]
# Out:
# 'd:\\python\\llm-scratch'

# %%
getRootPath()
# Out:
# 'd:\\python\\llm-scratch'

# %% [markdown]
# ### Try open and read file

# %%
filePath = os.path.join(getRootPath(), "checkpoint", "textLoad.txt")
f = open(filePath, mode="r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 2
#       1 filePath = os.path.join(getRootPath(), "checkpoint", "textLoad.txt")
# ----> 2 f = open(filePath, mode="r")
#
# File d:\python\llm-scratch\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\python\\llm-scratch\\checkpoint\\textLoad.txt'

# %%
f = open("..\\checkRead.txt", mode="r+")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 f = open("..\\checkRead.txt", mode="r+")
#
# File d:\python\llm-scratch\.venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '..\\checkRead.txt'
