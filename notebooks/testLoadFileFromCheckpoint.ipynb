# %%
import os
from config import CHECKPOINT_DIR
from pathlib import Path

from helper import getRootPath

# %% [markdown]
# ### Trial

# %%
targetPath = os.path.join(CHECKPOINT_DIR, "testLoad.txt")
print(targetPath)
# Out:
# checkpoint\testLoad.txt

# %%
ROOT_DIR = Path.cwd()
print(ROOT_DIR)
# Out:
# d:\llm-scratch\notebooks

# %%
currentPath = str(ROOT_DIR)

# %%
projectPath = currentPath.find("llm-scratch")

# %%
currentPath[0: projectPath + len("llm-scratch")]
# Out:
# 'd:\\llm-scratch'

# %%
getRootPath()
# Out:
# 'd:\\llm-scratch'

# %% [markdown]
# ### Try open and read file

# %% [markdown]
# D:\llm-scratch\checkpoint\testLoad.txt

# %%
filePath = os.path.join(getRootPath(), "checkpoint", "testLoad.txt")
print(filePath)
print("d:\\llm-scratch\\checkpoint\\testLoad.txt")
f = open(filePath, mode="r")
# Out:
# d:\llm-scratch\checkpoint\testLoad.txt
# d:\llm-scratch\checkpoint\testLoad.txt

# %%
f = open("checkRead.txt", mode="r+")

# %% [markdown]
# ### test attention

# %%
from transformer import Attention_init,Attention

# %%
attentionInit = Attention_init.randomInitial()

# %%
attention = Attention(attentionInit, name="testerAttention1")

# %%
attention.save_checkpoint()
# Out:
# Attention : testerAttention1, already save at the checkpoint @ d:\llm-scratch\checkpoint\testerAttention1.npz

# %%
copyingAttention = Attention.load_checkpoint(name="testerAttention1")

# %%
attention.Wk
# Out:
# array([[[0.18985741, 0.98399558, 0.66999717, 0.28038283, 0.20391323,
#          0.62506469],
#         [0.65260432, 0.89880753, 0.97476378, 0.15393237, 0.69908928,
#          0.44724145],
#         [0.01751321, 0.29102491, 0.38123661, 0.32102791, 0.94254467,
#          0.70266697],
#         [0.13645032, 0.34320907, 0.8119946 , 0.148494  , 0.05932569,
#          0.31441663],
#         [0.42015645, 0.80801771, 0.00950759, 0.45408379, 0.55868699,
#          0.00288863],
#         [0.29775757, 0.05379911, 0.56766875, 0.94055815, 0.72427372,
#          0.85637809]]])

# %%
copyingAttention.Wk
# Out:
# array([[[0.18985741, 0.98399558, 0.66999717, 0.28038283, 0.20391323,
#          0.62506469],
#         [0.65260432, 0.89880753, 0.97476378, 0.15393237, 0.69908928,
#          0.44724145],
#         [0.01751321, 0.29102491, 0.38123661, 0.32102791, 0.94254467,
#          0.70266697],
#         [0.13645032, 0.34320907, 0.8119946 , 0.148494  , 0.05932569,
#          0.31441663],
#         [0.42015645, 0.80801771, 0.00950759, 0.45408379, 0.55868699,
#          0.00288863],
#         [0.29775757, 0.05379911, 0.56766875, 0.94055815, 0.72427372,
#          0.85637809]]])
