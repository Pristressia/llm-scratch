# %%
from llm_architect import DataProcessor, helper_function, DATABASE_URL
import numpy as np

# %%
helper_function(30)
# Out:
# 60

# %%
A = np.random.rand(2, 4, 6)

# %%
A.sum(axis = (0, 1), keepdims=True)
# Out:
# array([[[2.75953892, 3.16195794, 3.85904728, 3.27654604, 3.79930788,
#          2.90238874]]])
